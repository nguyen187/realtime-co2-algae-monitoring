# %%
# !pip install ultralytics==8.0.48
# Out:
# ...
#   Using cached ultralytics-8.0.48-py3-none-any.whl (303 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached sentry_sdk-1.44.1-py2.py3-none-any.whl (266 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#      ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/731.7 MB 1.2 MB/s eta 0:07:57

# %%
# !unzip /content/BBB.v6i.yolov8.zip
# Out:
# Archive:  /content/BBB.v6i.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/no1_mp4-0005_jpg.rf.cd81cbe0b22810e7c386d4157dd2bbb6.jpg
#  extracting: test/images/no1_mp4-0027_jpg.rf.202e88939febdd9613169ed5a1fc0ca9.jpg
#  extracting: test/images/no1_mp4-0037_jpg.rf.1ab98c702181b46cb59f29f68585a272.jpg
#  extracting: test/images/no1_mp4-0038_jpg.rf.b557dc2cc2861b48f0e15cd4e826b96a.jpg
#  extracting: test/images/no1_mp4-0076_jpg.rf.792f1659c19e54673a8354f9f19d7b12.jpg
#  extracting: test/images/no1_mp4-0081_jpg.rf.330ce576ddf9ae3d3d818731b6b608ab.jpg
#  extracting: test/images/no1_mp4-0094_jpg.rf.ce6f96a8ed5411c7916af01d9fa2c43e.jpg
#  extracting: test/images/no1_mp4-0097_jpg.rf.139c798b573a66aa13bc6df4268d3585.jpg
#  extracting: test/images/no1_mp4-0144_jpg.rf.f468037330f822fcb48f3ea5d06afb2a.jpg
# ...

# %%
import os
ROOT_DIR = '/content'
from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=200,patience = 0,batch = 8)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/ComputerVisionDeveloper/TrainYolov8CustomDataset'
